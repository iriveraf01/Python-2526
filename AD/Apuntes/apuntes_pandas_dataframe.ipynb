# %% [markdown]
# # Pandas (Dataframe)

# %%
import pandas as pd
# DataFrame
df = pd.read_csv('barca_2015_partidos.csv')
print("Partidos del Barça en 2015:")
df.head()
# Out:
# Partidos del Barça en 2015:
#         Fecha Competición               Rival    Lugar  Goles_Barca  \
# 0  2015-01-04     La Liga       Real Sociedad     Casa            1
# 1  2015-01-11     La Liga  Atlético de Madrid    Fuera            3
# 2  2015-03-22     La Liga         Real Madrid     Casa            2
# 3  2015-05-17     La Liga  Atlético de Madrid    Fuera            1
# 4  2015-06-06   Champions            Juventus  Neutral            3
#
#    Goles_Rival
# 0            0
# 1            1
# 2            1
# 3            0
# 4            1
