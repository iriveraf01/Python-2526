# %%
import pandas as pd
from influxdb import InfluxDBClient

HOST = '192.168.1.8'
PUERTO = 8886
USER = 'pythonread'
PASS = 'read1234'
DATABASE = 'agro_sensex'

cliente = InfluxDBClient(host=HOST, port=PUERTO, username=USER, password=PASS, database=DATABASE)

resultado = cliente.ping()
print(resultado)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#       8 DATABASE = 'agro_sensex'
#      10 cliente = InfluxDBClient(host=HOST, port=PUERTO, username=USER, password=PASS, database=DATABASE)
# ---> 12 resultado = cliente.ping()
#      13 print(resultado)
#
# File ~/Escritorio/Python-2526/entorno_tareas/lib/python3.12/site-packages/influxdb/client.py:626, in InfluxDBClient.ping(self)
#     621 def ping(self):
#     622     """Check connectivity to InfluxDB.
#     623
#     624     :returns: The version of the InfluxDB the client is connected to
#     625     """
# --> 626     response = self.request(
#     627         url="ping",
#     628         method='GET',
#     629         expected_response_code=204
#     630     )
#     632     return response.headers['X-Influxdb-Version']
#
# ...

# %%
print(cliente.get_list_database())

# %%
cliente.switch_database(DATABASE)
resultado = cliente.query('SHOW MEASUREMENTS')
print(type(resultado))
print(resultado)
print(resultado.get_points())
