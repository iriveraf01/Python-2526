# %% [markdown]
# # Ejercicio 1
#
# Crea el siguiente programa en celda de código siguiendo paso a paso las instrucciones:
#
# 1. Ingresa en una lista una serie de palabras introducidas por teclado hasta que el usuario ingrese la palabra "fin". La palabra "fin" no se debe meter en la lista.
# 2. Posteriormente, pide una palabra específica al usuario, búscala en la lista y muestra su posición en la lista. Si la palabra existe, elimínala y muestra la lista de palabras para comprobar; si no, indica que no se encontró.

# %%
palabras = []
palabra = ""

while palabra != "fin":
    palabra = input("Introduce una palabra: ").lower()
    if palabra != "fin":
        palabras.append(palabra)


buscar = input("Introduce una palabra a buscar en la lista: ")

if buscar in palabras:
    posicion = palabras.index(buscar)
    print(f"La palabra '{buscar}' está en la posición {posicion}.")
    palabras.remove(buscar)
    print("Palabra eliminada. Lista actual:", palabras)
else:
    print(f"La palabra '{buscar}' no se encontró en la lista.")
# Out:
# La palabra 'fin' no se encontró en la lista.

# %% [markdown]
# # Ejercicio 2
#
# + Escribe un programa que permita al usuario ingresar una lista de números.
# + Luego, ordena la lista de menor a mayor y muéstrala.
# + Posteriormente, muestra cuántas veces aparece cada número en la lista.

# %%
numeros = []
cantidad = int(input("¿Cuántos números quieres agregar a la lista? "))

for _ in range(cantidad):
    numero = int(input("Ingresa un número: "))
    numeros.append(numero)

numeros.sort()
print("Lista ordenada:", numeros)

# Contar ocurrencias de cada número sin repetir conteos
numeros_contados = []
for numero in numeros:
    if numero not in numeros_contados:
        ocurrencias = numeros.count(numero)
        print(f"El número {numero} aparece {ocurrencias} veces.")
        numeros_contados.append(numero)

# %% [markdown]
# # Ejercicio 3: Numeros únicos de una Lista
#
# + Crea un programa que permita al usuario ingresar una lista de números hasta que se introduzca el 0.
# + Luego, crea una lista con los números sin duplicar de la lista original. Es decir, si la lista tiene [2, 1, 2, 3, 2], el resultado es [2, 1, 3]

# %%
numeros = []

while (numero:=float(input("Ingresa un número: "))) != 0:
    numeros.append(numero)

print("Lista original:", numeros)

# Eliminar duplicados
numeros_sin_duplicados = []
for numero in numeros:
    if numero not in numeros_sin_duplicados:
        numeros_sin_duplicados.append(numero)

print("Lista sin duplicados:", numeros_sin_duplicados)
